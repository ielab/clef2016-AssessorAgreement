# %% [markdown]
# # This is the notebook for the CLEF long paper:
#
# #### "Assessors Agreement: A Case Study across Assessor Type, Payment levels, Query Variations and Relevance Dimensions."
# #### Authored by Joao Palotti, Guido Zuccont, Johannes Bernhardt, Allan Hanbury and Lorraine Gouriot.
#
# ##### Questons can be directed to me at joaopalotti@gmail.com

# %% [markdown]
# # Understanding the CLEF data

# %% [markdown]
# Before starting the assessment analysis, lets try to explain what is the data that we are analysing here.
#
# All the data in this paper was provided by CLEF eHealth 2014 Task 2 Lab (https://github.com/CLEFeHealth/CLEFeHealth2015Task2) + we have additional assessments made by unpaid medical students and laypeople.
#
# In this ad-hoc information retrieval task, participants had to submit systems that answered queries in the medical domain. Specifically, queries were created based on images and vides of symptoms.
#
# Some examples are below, in this image (which is Table 1 in the paper).

# %%
from IPython.core.display import Image
Image('table1.png')
